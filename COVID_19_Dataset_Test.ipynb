# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavi-chowdary/Detection-of-COVID-19-Using-X-Ray/blob/master/COVID_19_Dataset_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install torchxrayvision
# Out:
#      |████████████████████████████████| 25.0MB 1.8MB/s
#      |████████████████████████████████| 1.9MB 43.6MB/s

# %%
import torchxrayvision as xrv

# %%
# !git clone https://github.com/ieee8023/covid-chestxray-dataset
# Out:
# Cloning into 'covid-chestxray-dataset'...
# remote: Enumerating objects: 3629, done.
# remote: Total 3629 (delta 0), reused 0 (delta 0), pack-reused 3629
# Receiving objects: 100% (3629/3629), 632.96 MiB | 36.52 MiB/s, done.
# Resolving deltas: 100% (1442/1442), done.
# Checking out files: 100% (1173/1173), done.

# %%
d = xrv.datasets.COVID19_Dataset(imgpath="covid-chestxray-dataset/images/",csvpath="covid-chestxray-dataset/metadata.csv")

# %%
import matplotlib.pyplot as plt

# %%
sample = d[10]

# %%
plt.imshow(sample["img"][0], cmap="gray");

# %%
import pandas as pd
pd.Series(dict(zip(d.pathologies,sample["lab"])))
# Out:
# Aspergillosis     0.0
# Aspiration        0.0
# Bacterial         0.0
# COVID-19          0.0
# Chlamydophila     0.0
# Fungal            0.0
# H1N1              0.0
# Herpes            0.0
# Influenza         0.0
# Klebsiella        0.0
# Legionella        0.0
# Lipoid            0.0
# MERS-CoV          0.0
# MRSA              0.0
# Mycoplasma        0.0
# No Finding        0.0
# Nocardia          0.0
# Pneumocystis      0.0
# Pneumonia         1.0
# SARS              1.0
# Staphylococcus    0.0
# Streptococcus     0.0
# Tuberculosis      0.0
# Varicella         0.0
# Viral             1.0
# dtype: float64

# %%
# full details about the image is available in the pandas csv
d.csv.iloc[0]
# Out:
# index                                                                     0
# patientid                                                                 2
# offset                                                                    0
# sex                                                                       M
# age                                                                      65
# finding                                            Pneumonia/Viral/COVID-19
# RT_PCR_positive                                                           Y
# survival                                                                  Y
# intubated                                                                 N
# intubation_present                                                        N
# went_icu                                                                  N
# in_icu                                                                    N
# needed_supplemental_O2                                                    Y
# extubated                                                               NaN
# temperature                                                             NaN
# pO2_saturation                                                          NaN
# leukocyte_count                                                         NaN
# neutrophil_count                                                        NaN
# lymphocyte_count                                                        NaN
# view                                                                     PA
# modality                                                              X-ray
# date                                                       January 22, 2020
# location                        Cho Ray Hospital, Ho Chi Minh City, Vietnam
# folder                                                               images
# filename                  auntminnie-a-2020_01_28_23_51_6665_2020_01_28_...
# doi                                                    10.1056/nejmc2001272
# url                       https://www.nejm.org/doi/full/10.1056/NEJMc200...
# license                                                                 NaN
# clinical_notes            On January 22, 2020, a 65-year-old man with a ...
# other_notes                                                             NaN
# Unnamed: 29                                                             NaN
# offset_day_int                                                            0
# Name: 0, dtype: object
